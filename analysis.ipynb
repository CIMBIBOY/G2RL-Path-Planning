# %%
import pickle
import matplotlib.pyplot as plt
import seaborn as sns

# %%
q_tbl = pickle.load(open('models/q_learning_table.pkl','rb'))
all_rewards = pickle.load(open('models/all_rewards.pkl','rb'))
r_win = pickle.load(open('models/rewards_window.pkl','rb'))

# %%
q_tbl
# Out:
# array([[ 8.62731014e-02, -5.65171148e-02, -6.04237795e-03,
#          8.19836310e-01, -2.04200599e-03],
#        [ 9.61203917e-02,  7.84504807e-02, -8.14375055e-03,
#         -4.04543201e-03,  2.48145717e-03],
#        [ 9.34527050e-02,  8.47060223e-02,  2.16892070e-02,
#         -5.73429483e-04,  1.40239666e-02],
#        ...,
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00]])

# %%
x = [k for k in range(len(r_win))]
y = r_win

plt.plot(x,y)
plt.show()
